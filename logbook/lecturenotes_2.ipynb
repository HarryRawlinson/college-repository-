# %% [markdown]
# LECTURE 2: PROGRAMING LANGUAGES
#
#
# this lecture covers:
# a brief history of programming languages
# how has programming changed over time
# why we have different programming languages
#
# "we have to understand the past to understand the present"
# Carl sagan
#
# why do we have computers ?
# computers are good at carrying out simple repetitive tasks quicker than a human could
# they cannot make mistakes the way a human can
# humans are good at solving complex problems although they are slower and more error-prone within repetitive tasks
#
# we also wanted an enviroment where we can input logic and the computer can execute it
#
# languages are a way for humans to communicate with computers
# early programming languages
# was low level machine code
# ( no abstraction from hardware )
#
# the first examples of computers were large complex machines that were programmed using manual switches and patch cables
# which made programming tedious and error-prone especially mechanical errors
#
# the first computer programmer was a woman named ada lovelace
# she wrote an algorithm for charles babbage's analytical engine in the mid 1800s
#
# other important early figures in programming are alan turnig and john von neumann
# alan turing is considered the father of computer science
# hes most famous for cracking enigma
# being gay and then being castrated by the country he helped save.
#
#
# first generation programming languages
#
# colossus was the first programmable digital computer it stil used plugs and switches to opperate
#
# in this time each computer had its own unique machine code
# so you had to know the low level language to begin to opperate
#
# second generation programming:
#
# programming then introduced assembly lnanguage
# they are stil low level and specific to cpu (no abstraction from hardware to hardware)
#
# third generation programming languages:
# these are finally getting to where the average person can understanda program just by looking at it youll find english words and functions rather than just 1s and 0s
# and the abillity to run the same code on multiple types of hardware (abstraction from hardware to hardware)
# examples of 3rd generation languages:
# fortran - scientific computing
# cobol - for business applications
# basic - beginners all
#
# if we never took this step we would have alot more barriers to running programs and we would care about what sort of cpu we have
#
#
# third generation languages are also more specialised as mentioned above they are suited to different tasks
#
# c and c++ are also 3rd generation languages which are fast and can be applied more generally to projects
#
# since this we have essentially created programming languages for every task imaginable
#
# compilers and interpreters:
# there are 2 main ways to execute code written in high level languages
#
# compilers:
# a compiler translates the entire program into machine code before it is run thus creating a second .exe file for example
# these run faster since they are totally pre translated but require more space in memory and they take time to compile in the first place making development slower if the files are tested often
#
#
#
# interpreters:
# interpreters translate and execute code line by line
#
# translation is faster than comipilation making development faster
# but execution is slower since each line must be translated before it is run
#
# c and c++ are compiled languages
#
# but
# python and javascript and php are interpreted languages
#
#
# python is what we will be using in this course to start out with
# its a great one to learn early on since its syntax is simple and easy to read
# but it also allows for complex programs to be written
# its in the top 3 most popular programming languages in the world
# and there are many jobs that require python knowledge
#
# python lacks memory effieciency and if it needs to run very quickly it may not be the best choice
#
# python is predicted to last a long time
# also like cobol which is still used in banking systems today even though its very old (1959)
#
# new languages take a long time to catch on Rust and Golang are newer and wil increase in usage over time
#
# while we have different programming languages they all share similar concepts
#
# sequential execution
# selection (if statements)
# iteration (loops)
# variables and data types
