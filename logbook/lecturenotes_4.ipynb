# %% [markdown]
# lecture:4
# "a programmers work"
#
#
# what we are called
# programmer developer software engineer software developer - basically all the same thing
# lecturer got really passionate about this lol he kept saying stop arguing about titles
#
# skills you actually need
# problem solving is the most important one apparently
# then knowing languages and tools
# teamwork and communication (its not just sitting alone in a dark room)
# version control - git
# knowing the standard tools for when your favourite ones arent there
#
# tools are personal
# this was cool - everyone uses different stuff and thats fine
# half the class on windows half on mac/linux
# vs code vs pycharm also about 50/50
# he said when you get a junior job they probably wont force you to use one IDE which is nice
# but you have to be able to explain why you picked yours and set it up on a fresh laptop
#
# customisation
# customise everything so it works for you
# for eyesight or rsi or just cos you like it
# he was sad about people using plain windows and default pycharm
# most IDEs can sync your settings to github or cloud now which is handy
#
# standard tools you still have to know even if you hate them
# basic windows folders
# basic linux/mac folders
# command line git (kill me)
# notepad and vi cos theyre always there
#
# agile stuff
# pretty much every company uses agile now
# daily standup - everyone says what they did yesterday what doing today and whats blocking them
# tasks come from issue tracker thing
# tasks sorted by how valuable they are and how long theyll take
# everything in git obviously
# you work on your own branch then merge to main
# loads of remote work now (45% in america he said)
#
# 2025 stack overflow survey bits
# 84% of devs use ai tools now (up from 76%)
# but only 33% trust it 46% dont
# experienced devs trust it the least lol
# python growing loads (+7% in a year) especially for ai and data
# vs code and visual studio still the most popular ides
# github beating jira now
# markdown still king for docs
#
# my thoughts
# didnt realise programming is so social - loads of talking and teamwork
# kinda relieved theres no single “right” setup
# bit scared of command line git tho - looks horrible
# guess ill have to learn it properly
#
# stuff i need to do now
# pick my tools and actually get good with them
# learn proper git not-just-github-desktop git
# customise my laptop so its not painful to use
# get used to the idea of standups and agile even though were only students
