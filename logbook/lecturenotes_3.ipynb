# %% [markdown]
# lecture 3:
# Computers and instructions
#
# in this lecture we will explore basic programming ideas
#
# we will meet the python interactive interpreter
#
# why python ?
# python is a high level interpreted language that is more so used generally than for a specialised programming
#
# its good for developing quickly and experimenting
#
# python isnt great if a program needs to run very quickly as it needs alot of memory to run programs
#
# the python interpreter
# the interpreter is the program that will execute python code
# this can be done once we are finished programming or we can use it interactively
#
# we should really be calling python programs sripts and we should call python a scripting language rather than a programming language though neither is really wrong
#
# computers use buses to transfer instructions from memory ( machine code )
# to the cpu which then processes these commands and then will then store other results in memory to be called later but also send outputs and recieve inputs from hardware
#
# abstraction:
# because python is a high level language to program with it we dont need to understand this process in too much detail
# but it is good to know this:
#
# Computers process values, stored in binary.
#
# These values are stored in the computer's memory.
#
# Arithmetic operations are carried out in the CPU.
#
# There is a small amount of memory in the CPU (in registers), with much more outside.
# For processing, values are copied to and from the CPU (which copying is slow).
#
# the python code we write when executed the cpu doesnt see the if statments our the prints the way we wrote the code they exclusively work with binary
#
# when a value is mentioned in a program
# the computer has to do a few steps to store it in memory
# it needs to remember:
#
# the datatype (integer)
# the characters (if it is a string )
# the value such as 42 if its a float or int
# these values need to be stored in a specific address so that we know where to look for them
# they are allocated memory according to the need to store the value
#
# bigger numbers = bigger memory required
# the name of the value is also stored and addressed and placed into a lookup table so the computer can search for this value later
#
#
# it may look something like this
# Address	    Value	     Type
# 0b101010	int
# The denary value 42 is stored (in binary) in memory at address 0x00000001.
#
# we know that the variable spam is locatied at 0x00000001	 this address
#
#
# so when this is used
#
# the name is located in the look up table and the value associated with the name can be called into output or input
#
# but not all values can work the same as integers ( althoughh boolean work similarly as they are represented as a 0 or 1 )
#
# but abstraction hides many of the individual differences to store other data types
#
#
# some data is made up of smaller elements like letters in a string
#
# strings are stored in memory by storing the first char ( character ) in unicode
# as well as the next character and so on
#
# and a type of null character to show the end of the string
# as addresses like in realife are next to each other like houses on a street
#
# heres an example of a string being stored
#
#
# Address  	Value	        Type
# 0x00000001	0b01110011	char
# 0x00000002	0b01110000	char
# 0x00000003	0b01100001	char
# 0x00000004	0b01101101	char
# 0x00000005	0b00000000	None
#
#
# THERE ARE LIMITATIONS THO
#
# the value of a integer is limited by the number of bits used to store one
# as are floats and the precision of the decimal place
# the length of a string is limited by the ammount of memory available
#
# although modern machines have gigbytes of memeory so this is rarely an isssue
# your not gonna worry about the size of a single string
#
# but processing a 1 gigabyte log file
#
# the cpus
# arithmetic logic unit haas to work very hard as it has to do all the mathmatical calculations to read the string and its addresses
#
# there are also other parts of the cpu that is important to this process
# the program control unit
# as it executes instructions and says what tasks to perform
#
# there are also registers with in the cpu addresses to store numbers for calculations
#
# program counters for example to show what has gone in and out
#
# the cpu has its own memeory too called cache
# this is a small amount of memory and is replaced often when it moves on to another task
# so its used frequantly during operaions to hold many different values and data although this is not where the program is stored
#
# this is stored in the main memory
# ( there are many types of memory a story for another time )
#
# the pc keeps track of the address the program is stored at and the pc will cue up the addresses of the invidual instructiosn within the program
#
# the instructions will be in binary as i said earlier
#
# and they will go through many different processes and stages of being mathmatically manipulated by the alu
# although most alus in common cpu arcitecture can only do a few things to numbers
#
# Suppose you can only count, add two values, and negate one value. How can you do the following?
#
#  Add two numbers together.
#  Subtract one number from another.
#  Multiply two numbers together.
#  Divide one number by another.
#
#  for instance comparing a number to 0 may sound like it cant be used for much but now you can determin if numbers are =
#  or if one is less than
#  or greater than another
#  odd or even
#
# errors in programming:
#
# there are 2 different errors in programming syntax errors (spelling mistakes)
#
# or logical errors ( misspeaking)
# they are also callled semantic errors too
#
# it happens when the programs output is parcially unintended
# Bugs really
