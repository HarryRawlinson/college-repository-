# %% [markdown]
# week 8 - 13th november 2025 - ai and elephants (copilot time)
#
# lecture was literally just github copilot demo
#
# what it is
# ai pair programmer in vs code
# suggests lines or whole functions as you type
# can write tests docstrings examples everything
# lecturer used it to add 15 slides to his own powerpoint lol
#
# examples he showed
# - wrote a perfect is_prime just from the docstring
# - fibonacci function instantly
# - turned buggy sum_to(n) into correct one
# - refactored terrible variable names
#
# rules for us
# using copilot = totally fine even encouraged
# copy pasting without understanding = cheating and obvious
# not using it = youre just slow
#
# free for students
# github student pack = unlimited copilot
# he said go do it tonight
#
# other stuff
# good comments and variable names matter even more now cos ai reads them
# never let it see secrets
# always test whatever it writes
#
# lab this week
# make a cli calculator using copilot then fix and test everything it gives you
#
# next week back to normal python i think
