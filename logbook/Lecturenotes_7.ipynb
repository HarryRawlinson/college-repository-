# %% [markdown]
# week 7 - 6th november 2025 - error handling
#
# happy path
# when everything works perfectly and user isnt an idiot
# thats the bit we all code first cos its fun
#
# sad path / exceptions
# everything else
# users WILL break your program in creative ways
#
# two ways to handle errors
#
# LBYL - look before you leap
# check everything is safe first
# old boring c-style
# code gets super messy
#
# EAFP - easier to ask forgiveness than permission
# just try the thing
# if it explodes → catch it with try/except
# this is the python way
# keeps code clean and happy path obvious
#
# we usually mix both a tiny bit
# like try/except around int(input())
# then normal if to check its not negative or zero
#
# can raise our own errors
# raise ValueError("oi positive numbers only")
#
# best loop until good input
# while True:
#     try:
#         size = int(input...)
#         if size > 0: return size
#     except ValueError:
#         pass
#     print("try again")
#
# my thoughts
# eafp is way nicer
# less code
# happy path stays readable
# gonna use this all the time now
