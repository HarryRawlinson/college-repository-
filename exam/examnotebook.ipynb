# %% [markdown]
# #Harry Rawlinson
# "i am submitting Exam paper 1"

# %% [markdown]
# when programming i work on my desktop with my perferred IDE which is visual studio code and use features like co pilot
# when i come across bugs i cant seem to wrap my head around in my code my usual routine is to leave my desk go get a coffee and imagine the problem while the kettle boils i find that when i come back to the problem i have an easier time spotting the issue.
# I also think that it helps to somtimes depict the code within a different format such as writing down the pseudo code and comparing it to what ive written line by line, ALTHOUGH most of the time co pilot does have the answer
#
# #  **BIG HEADER**
# ## _not as big header_
#
#
# fave films
# - spooky film
# - action film
# - bad film

# %%
num = int(input("Enter an integer"))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
def any_in_range(nums):
    for num in nums:
        if 0 <= num <= 100:
            return True
    return False
num = int(input("Enter an integer: "))
print(any_in_range([num]))

# %%
user_input = input("Enter a string: ")
unique_chars = set(user_input)
print("Number of unique characters:", len(unique_chars))
